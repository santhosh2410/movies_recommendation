# %% [markdown]
# ## Extracting the movies of 2020

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

tables = soup.find_all('table',class_='wikitable sortable')

len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df.head()
# Out:
#    Opening  Opening.1              Title  \
# 0  JANUARY          3         The Grudge
# 1  JANUARY         10         Underwater
# 2  JANUARY         10        Like a Boss
# 3  JANUARY         10      Three Christs
# 4  JANUARY         10  Inherit the Viper
#
#                                   Production company  \
# 0  Screen Gems / Stage 6 Films / Ghost House Pict...
# 1  20th Century Fox / TSG Entertainment / Chernin...
# 2                                 Paramount Pictures
# 3                                          IFC Films
# 4     Barry Films / Tycor International Film Company
#
#                                        Cast and crew Ref.
# 0  Nicolas Pesce (director/screenplay); Andrea Ri...  [2]
# 1  William Eubank (director); Brian Duffield, Ada...  [3]
# 2  Miguel Arteta (director); Sam Pitman, Adam Col...  [4]
# 3  Jon Avnet (director/screenplay); Eric Nazarian...  NaN
# 4  Anthony Jerjen (director); Andrew Crabtree (sc...  [5]

# %%
df_20 = df[['Title','Cast and crew']]
df_20.head()
# Out:
#                Title                                      Cast and crew
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '31370eb33aa123089b518141fd2f4347'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_20['genres'] = df_20['Title'].map(lambda x: get_genre(str(x)))
df.tail()
# Out:
# <ipython-input-10-9ec4d1b25d26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_20['genres'] = df_20['Title'].map(lambda x: get_genre(str(x)))
#       Opening  Opening.1                  Title  \
# 267  DECEMBER         25       We Can Be Heroes
# 268  DECEMBER         25      News of the World
# 269  DECEMBER         25  One Night in Miami...
# 270  DECEMBER         25  Promising Young Woman
# 271  DECEMBER         30      Pieces of a Woman
#
#                               Production company  \
# 267               Netflix / Troublemaker Studios
# 268  Universal Pictures / Perfect World Pictures
# 269                               Amazon Studios
# 270    Focus Features / FilmNation Entertainment
# 271                       Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 267  Robert Rodriguez (director/screenplay); Priyan...  [239]
# 268  Paul Greengrass (director/screenplay); Luke Da...  [240]
# 269  Regina King (director); Kemp Powers (screenpla...  [241]
# 270  Emerald Fennell (director/screenplay); Carey M...  [242]
# 271  Kornél Mundruczó (director); Kata Wéber (scree...  [243]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_20['director_name'] = df_20['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-12-505853974c65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_20['director_name'] = df_20['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_20['actor_1_name'] = df_20['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-14-284c8756d4c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_20['actor_1_name'] = df_20['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_20['actor_2_name'] = df_20['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_20['actor_3_name'] = df_20['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_20.tail()
# Out:
#                      Title                                      Cast and crew  \
# 267       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 268      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 269  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 270  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 271      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                              genres     director_name           actor_1_name  \
# 267    Action Fantasy Family Comedy  Robert Rodriguez  Priyanka Chopra Jonas
# 268  Action Adventure Drama Western   Paul Greengrass              Tom Hanks
# 269                           Drama       Regina King      Kingsley Ben-Adir
# 270            Thriller Crime Drama   Emerald Fennell         Carey Mulligan
# 271                           Drama  Kornél Mundruczó          Vanessa Kirby
#
#       actor_2_name   actor_3_name
# 267   Pedro Pascal  YaYa Gosselin
# 268  Helena Zengel            NaN
# 269      Eli Goree    Aldis Hodge
# 270     Bo Burnham    Alison Brie
# 271   Shia LaBeouf   Molly Parker

# %%
df_20 = df_20.rename(columns={'Title':'movie_title'})
df_20.head()
# Out:
#          movie_title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                    genres   director_name        actor_1_name  \
# 0                 Horror Mystery Thriller   Nicolas Pesce  Andrea Riseborough
# 1  Action Horror Science Fiction Thriller  William Eubank     Kristen Stewart
# 2                                  Comedy   Miguel Arteta     Tiffany Haddish
# 3                                   Drama       Jon Avnet        Richard Gere
# 4                    Drama Thriller Crime  Anthony Jerjen       Josh Hartnett
#
#         actor_2_name     actor_3_name
# 0      Demián Bichir         John Cho
# 1     Vincent Cassel  Jessica Henwick
# 2         Rose Byrne      Salma Hayek
# 3     Peter Dinklage   Walton Goggins
# 4  Margarita Levieva   Chandler Riggs

# %%
df_20['comb'] = df_20['actor_1_name'] + ' ' + df_20['actor_2_name'] + ' '+ df_20['actor_3_name'] + ' '+ df_20['director_name'] +' ' + df_20['genres']

# %% [markdown]
# ## Extracting the movies of 2021

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

tables = soup.find_all('table',class_='wikitable sortable')

len(tables)
# Out:
# 4

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df_21 = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df_21.head()
# Out:
#    Opening  Opening.1                Title               Production company  \
# 0  JANUARY        1.0  Shadow in the Cloud           Vertical Entertainment
# 1  JANUARY       13.0      The White Tiger                          Netflix
# 2  JANUARY       14.0          Locked Down  HBO Max / Warner Bros. Pictures
# 3  JANUARY       15.0              The Dig      Netflix / Clerkenwell Films
# 4  JANUARY       15.0     Outside the Wire                          Netflix
#
#                                        Cast and crew  Ref Ref.
# 0  Roseanne Liang (director/screenplay); Max Land...  [2]  NaN
# 1  Ramin Bahrani (director/screenplay); Adarsh Go...  NaN  NaN
# 2  Doug Liman (director); Steven Knight (screenpl...  [3]  NaN
# 3  Simon Stone (director); Moira Buffini (screenp...  [4]  NaN
# 4  Mikael Håfström (director); Rob Yescombe, Rowa...  [5]  NaN

# %%
df_21 = df_21[['Title','Cast and crew']]
df_21.head()
# Out:
#                  Title                                      Cast and crew
# 0  Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1      The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2          Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3              The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4     Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...

# %%
df_21['genres'] = df_21['Title'].map(lambda x: get_genre(str(x)))
df_21.tail()
# Out:
#                Title                                      Cast and crew  \
# 223     The Matrix 4  Lana Wachowski (director/screenplay); Aleksand...
# 224           Sing 2  Garth Jennings (director/screenplay); Matthew ...
# 225   The King's Man  Matthew Vaughn (director/screenplay); Karl Gaj...
# 226  Downton Abbey 2  Simon Curtis (director); Julian Fellowes (scre...
# 227           Cyrano  Joe Wright (director); Erica Schmidt (screenpl...
#
#                             genres
# 223         Action Science Fiction
# 224  Music Animation Comedy Family
# 225        Action Adventure Comedy
# 226                          Drama
# 227   Drama Comedy History Romance

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_21['director_name'] = df_21['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_21['actor_1_name'] = df_21['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_21['actor_2_name'] = df_21['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_21['actor_3_name'] = df_21['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_21 = df_21.rename(columns={'Title':'movie_title'})
df_21.tail(100)
# Out:
#                                            movie_title  \
# 128                                         Fatherhood
# 129                                  The Birthday Cake
# 130  Rita Moreno: Just a Girl Who Decided to Go for It
# 131       Truman & Tennessee: An Intimate Conversation
# 132                               A Crime on the Bayou
# ..                                                 ...
# 223                                       The Matrix 4
# 224                                             Sing 2
# 225                                     The King's Man
# 226                                    Downton Abbey 2
# 227                                             Cyrano
#
#                                          Cast and crew  \
# 128  Paul Weitz (director/screenplay); Dana Stevens...
# 129  Jimmy Giannopoulos (director/screenplay); Diom...
# 130  Mariem Pérez Riera (director/screenplay); Rita...
# 131  Lisa Immordino Vreeland (director/screenplay);...
# 132  Nancy Buirski (director/screenplay); Gary Dunc...
# ..                                                 ...
# 223  Lana Wachowski (director/screenplay); Aleksand...
# 224  Garth Jennings (director/screenplay); Matthew ...
# 225  Matthew Vaughn (director/screenplay); Karl Gaj...
# 226  Simon Curtis (director); Julian Fellowes (scre...
# 227  Joe Wright (director); Erica Schmidt (screenpl...
#
#                             genres            director_name  \
# 128            Drama Family Comedy               Paul Weitz
# 129                 Crime Thriller       Jimmy Giannopoulos
# 130                    Documentary       Mariem Pérez Riera
# 131                    Documentary  Lisa Immordino Vreeland
# 132                    Documentary            Nancy Buirski
# ..                             ...                      ...
# 223         Action Science Fiction           Lana Wachowski
# 224  Music Animation Comedy Family           Garth Jennings
# 225        Action Adventure Comedy           Matthew Vaughn
# 226                          Drama             Simon Curtis
# 227   Drama Comedy History Romance               Joe Wright
#
#             actor_1_name       actor_2_name           actor_3_name
# 128           Kevin Hart      Alfre Woodard         Lil Rel Howery
# 129     Shiloh Fernandez         Val Kilmer          Ewan McGregor
# 130          Rita Moreno       Eva Longoria        George Chakiris
# 131          Jim Parsons     Zachary Quinto                    NaN
# 132          Gary Duncan      Richard Sobol                    NaN
# ..                   ...                ...                    ...
# 223         Keanu Reeves   Carrie-Anne Moss  Yahya Abdul-Mateen II
# 224  Matthew McConaughey  Reese Witherspoon     Scarlett Johansson
# 225        Ralph Fiennes     Gemma Arterton             Rhys Ifans
# 226      Hugh Bonneville         Jim Carter       Michelle Dockery
# 227       Peter Dinklage      Haley Bennett         Ben Mendelsohn
#
# [100 rows x 7 columns]

# %%
df_21['comb'] = df_21['actor_1_name'] + ' ' + df_21['actor_2_name'] + ' '+ df_21['actor_3_name'] + ' '+ df_21['director_name'] +' ' + df_21['genres']
df_21.head()
# Out:
#            movie_title                                      Cast and crew  \
# 0  Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1      The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2          Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3              The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4     Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
#
#                             genres    director_name        actor_1_name  \
# 0                Horror Action War   Roseanne Liang  Chloë Grace Moretz
# 1                      Crime Drama    Ramin Bahrani       Adarsh Gourav
# 2               Comedy Crime Drama       Doug Liman       Anne Hathaway
# 3                    Drama History      Simon Stone      Carey Mulligan
# 4  Thriller Action Science Fiction  Mikael Håfström      Anthony Mackie
#
#         actor_2_name           actor_3_name  \
# 0  Taylor John Smith           Beulah Koale
# 1      Rajkummar Rao  Priyanka Chopra Jonas
# 2   Chiwetel Ejiofor       Stephen Merchant
# 3      Ralph Fiennes             Lily James
# 4       Damson Idris          Emily Beecham
#
#                                                 comb
# 0  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4  Anthony Mackie Damson Idris Emily Beecham Mika...

# %%
new_df = df_20.append(df_21,ignore_index=True)
new_df.head()
# Out:
#          movie_title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                    genres   director_name        actor_1_name  \
# 0                 Horror Mystery Thriller   Nicolas Pesce  Andrea Riseborough
# 1  Action Horror Science Fiction Thriller  William Eubank     Kristen Stewart
# 2                                  Comedy   Miguel Arteta     Tiffany Haddish
# 3                                   Drama       Jon Avnet        Richard Gere
# 4                    Drama Thriller Crime  Anthony Jerjen       Josh Hartnett
#
#         actor_2_name     actor_3_name  \
# 0      Demián Bichir         John Cho
# 1     Vincent Cassel  Jessica Henwick
# 2         Rose Byrne      Salma Hayek
# 3     Peter Dinklage   Walton Goggins
# 4  Margarita Levieva   Chandler Riggs
#
#                                                 comb
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# 1  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4  Josh Hartnett Margarita Levieva Chandler Riggs...

# %%
old_df = pd.read_csv('C:/Users/SANTHOSH/Desktop/practise/flask/movie_recommandation/datasets/final_data.csv')
old_df.tail(100)
# Out:
#                        director_name       actor_1_name          actor_2_name  \
# 5757                   André Øvredal       Zoe Colletti         Michael Garza
# 5758  Tyler Nilson, Michael Schwartz       Shia LaBeouf        Dakota Johnson
# 5759                 Bart Freundlich  Michelle Williams        Julianne Moore
# 5760                   Casey Affleck      Casey Affleck         Anna Pniowsky
# 5761                Thurop Van Orman     Jason Sudeikis              Josh Gad
# ...                              ...                ...                   ...
# 5852          Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5853                    Greta Gerwig      Saoirse Ronan           Emma Watson
# 5854                      Sam Mendes      George MacKay  Dean-Charles Chapman
# 5855           Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5856                 Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#        actor_3_name                                    genres  \
# 5757   Gabriel Rush                           Horror Thriller
# 5758    John Hawkes                    Adventure Drama Comedy
# 5759   Billy Crudup                                     Drama
# 5760      Tom Bower                     Science Fiction Drama
# 5761   Leslie Jones         Animation Comedy Adventure Family
# ...             ...                                       ...
# 5852  Rashida Jones  Animation Action Adventure Comedy Family
# 5853  Florence Pugh                             Drama Romance
# 5854    Mark Strong                 War Drama Action Thriller
# 5855    Brie Larson                       Drama Crime History
# 5856    Aldis Hodge                                     Drama
#
#                             movie_title  \
# 5757  scary stories to tell in the dark
# 5758           the peanut butter falcon
# 5759                  after the wedding
# 5760                   light of my life
# 5761            the angry birds movie 2
# ...                                 ...
# 5852                  spies in disguise
# 5853                       little women
# 5854                               1917
# 5855                         just mercy
# 5856                           clemency
#
#                                                    comb
# 5757  Zoe Colletti Michael Garza Gabriel Rush André ...
# 5758  Shia LaBeouf Dakota Johnson John Hawkes Tyler ...
# 5759  Michelle Williams Julianne Moore Billy Crudup ...
# 5760  Casey Affleck Anna Pniowsky Tom Bower Casey Af...
# 5761  Jason Sudeikis Josh Gad Leslie Jones Thurop Va...
# ...                                                 ...
# 5852  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5853  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5854  George MacKay Dean-Charles Chapman Mark Strong...
# 5855  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5856  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [100 rows x 7 columns]

# %%
final_df = old_df.append(new_df,ignore_index=True)
final_df.head(200)
# Out:
#          director_name     actor_1_name      actor_2_name  \
# 0        James Cameron      CCH Pounder  Joel David Moore
# 1       Gore Verbinski      Johnny Depp     Orlando Bloom
# 2           Sam Mendes  Christoph Waltz      Rory Kinnear
# 3    Christopher Nolan        Tom Hardy    Christian Bale
# 4          Doug Walker      Doug Walker        Rob Walker
# ..                 ...              ...               ...
# 195        Tony Gilroy    Jeremy Renner       Scott Glenn
# 196    Joel Schumacher    Michael Gough     Vivica A. Fox
# 197         Ron Howard     Clint Howard        T.J. Thyne
# 198    Roland Emmerich  Jake Gyllenhaal      Dennis Quaid
# 199           John Woo       Tom Cruise     Dougray Scott
#
#              actor_3_name                            genres  \
# 0               Wes Studi   Action Adventure Fantasy Sci-Fi
# 1          Jack Davenport          Action Adventure Fantasy
# 2        Stephanie Sigman         Action Adventure Thriller
# 3    Joseph Gordon-Levitt                   Action Thriller
# 4                 unknown                       Documentary
# ..                    ...                               ...
# 195           Stacy Keach         Action Adventure Thriller
# 196           John Glover                            Action
# 197         Molly Shannon             Comedy Family Fantasy
# 198             Sela Ward  Action Adventure Sci-Fi Thriller
# 199      Richard Roxburgh         Action Adventure Thriller
#
#                                            movie_title  \
# 0                                               avatar
# 1             pirates of the caribbean: at world's end
# 2                                              spectre
# 3                                the dark knight rises
# 4    star wars: episode vii - the force awakens    ...
# ..                                                 ...
# 195                                  the bourne legacy
# 196                                     batman & robin
# 197                     how the grinch stole christmas
# 198                             the day after tomorrow
# 199                             mission: impossible ii
#
#                                                   comb Cast and crew
# 0    CCH Pounder Joel David Moore Wes Studi James C...           NaN
# 1    Johnny Depp Orlando Bloom Jack Davenport Gore ...           NaN
# 2    Christoph Waltz Rory Kinnear Stephanie Sigman ...           NaN
# 3    Tom Hardy Christian Bale Joseph Gordon-Levitt ...           NaN
# 4    Doug Walker Rob Walker unknown Doug Walker Doc...           NaN
# ..                                                 ...           ...
# 195  Jeremy Renner Scott Glenn Stacy Keach Tony Gil...           NaN
# 196  Michael Gough Vivica A. Fox John Glover Joel S...           NaN
# 197  Clint Howard T.J. Thyne Molly Shannon Ron Howa...           NaN
# 198  Jake Gyllenhaal Dennis Quaid Sela Ward Roland ...           NaN
# 199  Tom Cruise Dougray Scott Richard Roxburgh John...           NaN
#
# [200 rows x 8 columns]

# %%
final_df.isna().sum()
# Out:
# director_name       0
# actor_1_name        0
# actor_2_name        8
# actor_3_name       41
# genres              3
# movie_title         2
# comb               42
# Cast and crew    5859
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# Cast and crew    0
# dtype: int64

# %%
final_df.to_csv('C:/Users/SANTHOSH/Desktop/practise/flask/movie_recommandation/datasets/finalz_data.csv',index=False)
