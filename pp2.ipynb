# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('C:/Users/SANTHOSH/Desktop/practise/flask/movie_recommandation/datasets/credits.csv')
df1.tail(15)
# Out:
#                                                     cast  \
# 45461  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45462                                                 []
# 45463  [{'cast_id': 1, 'character': 'Devki Sabarwal',...
# 45464  [{'cast_id': 0, 'character': 'Lauren', 'credit...
# 45465  [{'cast_id': 5, 'character': '', 'credit_id': ...
# 45466  [{'cast_id': 5, 'character': 'The Creeper', 'c...
# 45467  [{'cast_id': 30, 'character': 'Debuty Hank Har...
# 45468  [{'cast_id': 2, 'character': 'Branwall', 'cred...
# 45469  [{'cast_id': 1, 'character': 'Kira (as Cassand...
# 45470  [{'cast_id': 1, 'character': 'Sir Robert Hode'...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 45461  [{'credit_id': '52fe4a71c3a36847f81ce35b', 'de...  106807
# 45462  [{'credit_id': '539ef1090e0a263dd00000d7', 'de...  276895
# 45463  [{'credit_id': '58ee55bbc3a3683df500bd0f', 'de...  404604
# 45464  [{'credit_id': '587626f4c3a3682b33008299', 'de...  420346
# 45465  [{'credit_id': '5330178a9251413a720055e3', 'de...   67179
# 45466  [{'credit_id': '58152c139251415a7f0047e2', 'de...   84419
# 45467  [{'credit_id': '56ff6ddbc3a3686e9e0013bc', 'de...  390959
# 45468  [{'credit_id': '5403d669c3a3682d9800427d', 'de...  289923
# 45469  [{'credit_id': '5757f36ac3a3687d6f000e8a', 'de...  222848
# 45470  [{'credit_id': '52fe44439251416c9100a899', 'de...   30840
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257

# %%
df2=pd.read_csv('C:/Users/SANTHOSH/Desktop/practise/flask/movie_recommandation/datasets/movies_metadata.csv')
df2.tail(10)
# Out:
# C:\Users\SANTHOSH\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        adult belongs_to_collection budget  \
# 45456  False                   NaN      0
# 45457  False                   NaN      0
# 45458  False                   NaN      0
# 45459  False                   NaN      0
# 45460  False                   NaN      0
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45456  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 45457  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 45458                     [{'id': 27, 'name': 'Horror'}]
# 45459           [{'id': 878, 'name': 'Science Fiction'}]
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45456                                   NaN   84419  tt0038621
# 45457                                   NaN  390959  tt0265736
# 45458                                   NaN  289923  tt0252966
# 45459                                   NaN  222848  tt0112613
# 45460                                   NaN   30840  tt0102797
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language             original_title  \
# 45456                en           House of Horrors
# 45457                en  Shadow of the Blair Witch
# 45458                en        The Burkittsville 7
# 45459                en            Caged Heat 3000
# 45460                en                 Robin Hood
# 45461                fa                    رگ خواب
# 45462                tl        Siglo ng Pagluluwal
# 45463                en                   Betrayal
# 45464                en        Satana likuyushchiy
# 45465                en                   Queerama
#
#                                                 overview  ... release_date  \
# 45456  An unsuccessful sculptor saves a madman named ...  ...   1946-03-29
# 45457  In this true-crime documentary, we delve into ...  ...   2000-10-22
# 45458  A film archivist revisits the story of Rustin ...  ...   2000-10-03
# 45459  It's the year 3000 AD. The world's most danger...  ...   1995-01-01
# 45460  Yet another version of the classic epic, with ...  ...   1991-05-13
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#       revenue runtime                          spoken_languages    status  \
# 45456     0.0    65.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45457     0.0    45.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45458     0.0    30.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45459     0.0    85.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45460     0.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45461     0.0    90.0    [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462     0.0   360.0         [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464     0.0    87.0                                        []  Released
# 45465     0.0    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 45456                                Meet...The CREEPER!
# 45457                                                NaN
# 45458  Do you know what happened 50 years before "The...
# 45459                                                NaN
# 45460                                                NaN
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                            title  video vote_average vote_count
# 45456           House of Horrors  False          6.3        8.0
# 45457  Shadow of the Blair Witch  False          7.0        2.0
# 45458        The Burkittsville 7  False          7.0        1.0
# 45459            Caged Heat 3000  False          3.5        1.0
# 45460                 Robin Hood  False          5.7       26.0
# 45461                     Subdue  False          4.0        1.0
# 45462        Century of Birthing  False          9.0        3.0
# 45463                   Betrayal  False          3.8        6.0
# 45464           Satan Triumphant  False          0.0        0.0
# 45465                   Queerama  False          0.0        0.0
#
# [10 rows x 24 columns]

# %%
df2['release_date'] = pd.to_datetime(df2['release_date'], errors='coerce')

df2['year'] = df2['release_date'].dt.year

df2['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
# Getting only 2017 movies as we already have movies up to the year 2016 in preprocessing 1 file. 
# We don't have enough data for the movies from 2018, 2019 and 2020. 
# We'll deal with it in the upcoming preprocessing files
df2 = df2.loc[df2.year == 2017,['genres','id','title','year']]

# %%
df2['id'] = df2['id'].astype(int)

# %%
data = pd.merge(df1, df2, on='id')

pd.set_option('display.max_colwidth', 75)
data
# Out:
#                                                                            cast  \
# 0    [{'cast_id': 1, 'character': 'Captain Jack Sparrow', 'credit_id': '52fe...
# 1    [{'cast_id': 2, 'character': 'Bruce Wayne / Batman', 'credit_id': '535e...
# 2    [{'cast_id': 0, 'character': 'Thor Odinson', 'credit_id': '545d46a80e0a...
# 3    [{'cast_id': 3, 'character': 'Peter Quill / Star-Lord', 'credit_id': '5...
# 4    [{'cast_id': 0, 'character': 'King Louis XIV', 'credit_id': '5431dd580e...
# ..                                                                          ...
# 526  [{'cast_id': 0, 'character': 'Satu', 'credit_id': '597e2086c3a368544001...
# 527  [{'cast_id': 0, 'character': 'Detective Simmons', 'credit_id': '593ba04...
# 528                                                                          []
# 529  [{'cast_id': 1, 'character': 'Devki Sabarwal', 'credit_id': '577809adc3...
# 530                                                                          []
#
#                                                                            crew  \
# 0    [{'credit_id': '52fe4c9cc3a36847f8236a65', 'department': 'Production', ...
# 1    [{'credit_id': '55ef66dbc3a3686f1700a52d', 'department': 'Production', ...
# 2    [{'credit_id': '56a93fa4c3a36872db001e7a', 'department': 'Writing', 'ge...
# 3    [{'credit_id': '59171547925141583c0315a6', 'department': 'Sound', 'gend...
# 4    [{'credit_id': '5431de49c3a36825d300007e', 'department': 'Directing', '...
# ..                                                                          ...
# 526  [{'credit_id': '597e22f69251415d7801c74a', 'department': 'Directing', '...
# 527  [{'credit_id': '593ba0c29251410593009be3', 'department': 'Writing', 'ge...
# 528  [{'credit_id': '5981a15c92514151e0011b51', 'department': 'Sound', 'gend...
# 529  [{'credit_id': '58ee55bbc3a3683df500bd0f', 'department': 'Sound', 'gend...
# 530  [{'credit_id': '593e676c92514105b702e68e', 'department': 'Directing', '...
#
#          id  \
# 0    166426
# 1    141052
# 2    284053
# 3    283995
# 4    245842
# ..      ...
# 526  468707
# 527  461297
# 528  455661
# 529  404604
# 530  461257
#
#                                                                          genres  \
# 0    [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': ...
# 1    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 3    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 4    [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12...
# ..                                                                          ...
# 526            [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 527  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, ...
# 528  [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id...
# 529  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, '...
# 530                                                                          []
#
#                                                 title    year
# 0    Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 1                                      Justice League  2017.0
# 2                                      Thor: Ragnarok  2017.0
# 3                      Guardians of the Galaxy Vol. 2  2017.0
# 4                                 The King's Daughter  2017.0
# ..                                                ...     ...
# 526                  Thick Lashes of Lauri Mäntyvaara  2017.0
# 527                       Cop and a Half: New Recruit  2017.0
# 528                                    In a Heartbeat  2017.0
# 529                                               Mom  2017.0
# 530                                          Queerama  2017.0
#
# [531 rows x 6 columns]

# %%
# evaluates an expression node or a string containing a Python literal or container display
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

data['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: object

# %%
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

print(data['actor_1_name'])
print('------------------')
print(data['actor_2_name'])
print('------------------')
print(data['actor_3_name'])
print('------------------')
# Out:
# 0               Johnny Depp
# 1               Ben Affleck
# 2           Chris Hemsworth
# 3               Chris Pratt
# 4            Pierce Brosnan
#                ...
# 526          Inka Haapamäki
# 527    Lou Diamond Phillips
# 528                     NaN
# 529          Sridevi Kapoor
# 530                     NaN
# Name: actor_1_name, Length: 531, dtype: object
# ------------------
# 0       Javier Bardem
# 1        Henry Cavill
# 2      Tom Hiddleston
# 3         Zoe Saldana
# 4        William Hurt
#             ...
# 526     Rosa Honkonen
# 527     Wallace Shawn
# 528               NaN
# 529         Sajal Ali
# 530               NaN
# Name: actor_2_name, Length: 531, dtype: object
# ------------------
# 0        Geoffrey Rush
# 1            Gal Gadot
# 2       Cate Blanchett
# 3        Dave Bautista
# 4      Benjamin Walker
#             ...
# 526     Tiitus Rantala
# 527        Gina Holden
# 528                NaN
# 529     Akshaye Khanna
# 530                NaN
# Name: actor_3_name, Length: 531, dtype: object
# ------------------

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))
data['director_name']
# Out:
# 0      Joachim Rønning Espen Sandberg
# 1                         Zack Snyder
# 2                       Taika Waititi
# 3                          James Gunn
# 4                       Sean McNamara
#                     ...
# 526                  Hannaleena Hauru
# 527             Jonathan A. Rosenbaum
# 528          Beth David Esteban Bravo
# 529                      Ravi Udyawar
# 530                     Daisy Asquith
# Name: director_name, Length: 531, dtype: object

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

movie.tail()
# Out:
#                 director_name          actor_1_name   actor_2_name  \
# 526          Hannaleena Hauru        Inka Haapamäki  Rosa Honkonen
# 527     Jonathan A. Rosenbaum  Lou Diamond Phillips  Wallace Shawn
# 528  Beth David Esteban Bravo                   NaN            NaN
# 529              Ravi Udyawar        Sridevi Kapoor      Sajal Ali
# 530             Daisy Asquith                   NaN            NaN
#
#        actor_3_name                      genres_list  \
# 526  Tiitus Rantala                   Romance Comedy
# 527     Gina Holden       Crime Comedy Action Family
# 528             NaN  Family Animation Romance Comedy
# 529  Akshaye Khanna             Crime Drama Thriller
# 530             NaN                              NaN
#
#                                 title
# 526  Thick Lashes of Lauri Mäntyvaara
# 527       Cop and a Half: New Recruit
# 528                    In a Heartbeat
# 529                               Mom
# 530                          Queerama

# %%
movie = movie.dropna(how='any')
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

movie['movie_title'] = movie['movie_title'].str.lower()

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie.head(20)
# Out:
#                       director_name      actor_1_name        actor_2_name  \
# 0    Joachim Rønning Espen Sandberg       Johnny Depp       Javier Bardem
# 1                       Zack Snyder       Ben Affleck        Henry Cavill
# 2                     Taika Waititi   Chris Hemsworth      Tom Hiddleston
# 3                        James Gunn       Chris Pratt         Zoe Saldana
# 4                     Sean McNamara    Pierce Brosnan        William Hurt
# 5                       Adam Spinks   Ben Loyd-Holmes           Sarah Mac
# 6                 Rucha Humnabadkar         Ali Fazal     Melanie Chandra
# 7                  Sarik Andreasyan  Anton Pampushnyy     Sanzhar Madiyev
# 8                   Peter Hutchings  Victoria Justice           Eden Sher
# 9                     Patty Jenkins         Gal Gadot          Chris Pine
# 10                     Kevin Munroe      Chris Murphy   Ian James Corlett
# 11                   James Ponsoldt       Emma Watson           Tom Hanks
# 12                        Trish Sie     Anna Kendrick        Rebel Wilson
# 14                       Sean Byrne       Ethan Embry       Shiri Appleby
# 15                  Roberto Doveris  Violeta Castillo      Ingrid Isensee
# 16                    Lloyd Kaufman      Asta Paredes  Catherine Corcoran
# 17                    David Jackson   Amanda Leighton  Samantha Boscarino
# 18                   Demetri Martin    Demetri Martin      Gillian Jacobs
# 19  Alexandre Bustillo Julien Maury     Stephen Dorff         Lili Taylor
# 20                 Johannes Roberts       Claire Holt         Mandy Moore
#
#        actor_3_name                                    genres  \
# 0     Geoffrey Rush           Adventure Action Fantasy Comedy
# 1         Gal Gadot           Action Adventure Fantasy Sci-Fi
# 2    Cate Blanchett           Action Adventure Fantasy Sci-Fi
# 3     Dave Bautista            Action Adventure Comedy Sci-Fi
# 4   Benjamin Walker                  Fantasy Action Adventure
# 5       Neil Newbon                        Thriller Adventure
# 6        Omi Vaidya                              Drama Comedy
# 7   Sebastien Sisak                     Action Fantasy Sci-Fi
# 8   Ashley Rickards                                    Comedy
# 9      Robin Wright                  Action Adventure Fantasy
# 10       Matt Olsen  Animation Adventure Comedy Action Family
# 11      John Boyega                     Drama Thriller Sci-Fi
# 12    Brittany Snow                                    Comedy
# 14     Kiara Glasco                                    Horror
# 15    Mauricio Vaca                                     Drama
# 16        Zac Amino                             Comedy Horror
# 17   Hannah Kasulka                         TV Movie Thriller
# 18  Christine Woods                                    Comedy
# 19       Sam Strike                                    Horror
# 20    Chris Johnson           Drama Thriller Horror Adventure
#
#                                          movie_title  \
# 0   pirates of the caribbean: dead men tell no tales
# 1                                     justice league
# 2                                     thor: ragnarok
# 3                     guardians of the galaxy vol. 2
# 4                                the king's daughter
# 5                     extinction: nature has evolved
# 6                                 for here or to go?
# 7                                          guardians
# 8                                       the outcasts
# 9                                       wonder woman
# 10                                        sly cooper
# 11                                        the circle
# 12                                   pitch perfect 3
# 14                                 the devil's candy
# 15                                       las plantas
# 16   return to return to nuke 'em high, aka volume 2
# 17                           the cheerleader murders
# 18                                              dean
# 19                                       leatherface
# 20                                    47 meters down
#
#                                                                           comb
# 0   Johnny Depp Javier Bardem Geoffrey Rush Joachim Rønning Espen Sandberg ...
# 1   Ben Affleck Henry Cavill Gal Gadot Zack Snyder Action Adventure Fantasy...
# 2   Chris Hemsworth Tom Hiddleston Cate Blanchett Taika Waititi Action Adve...
# 3   Chris Pratt Zoe Saldana Dave Bautista James Gunn Action Adventure Comed...
# 4   Pierce Brosnan William Hurt Benjamin Walker Sean McNamara Fantasy Actio...
# 5         Ben Loyd-Holmes Sarah Mac Neil Newbon Adam Spinks Thriller Adventure
# 6          Ali Fazal Melanie Chandra Omi Vaidya Rucha Humnabadkar Drama Comedy
# 7   Anton Pampushnyy Sanzhar Madiyev Sebastien Sisak Sarik Andreasyan Actio...
# 8            Victoria Justice Eden Sher Ashley Rickards Peter Hutchings Comedy
# 9     Gal Gadot Chris Pine Robin Wright Patty Jenkins Action Adventure Fantasy
# 10  Chris Murphy Ian James Corlett Matt Olsen Kevin Munroe Animation Advent...
# 11      Emma Watson Tom Hanks John Boyega James Ponsoldt Drama Thriller Sci-Fi
# 12                   Anna Kendrick Rebel Wilson Brittany Snow Trish Sie Comedy
# 14                    Ethan Embry Shiri Appleby Kiara Glasco Sean Byrne Horror
# 15         Violeta Castillo Ingrid Isensee Mauricio Vaca Roberto Doveris Drama
# 16       Asta Paredes Catherine Corcoran Zac Amino Lloyd Kaufman Comedy Horror
# 17  Amanda Leighton Samantha Boscarino Hannah Kasulka David Jackson TV Movi...
# 18         Demetri Martin Gillian Jacobs Christine Woods Demetri Martin Comedy
# 19  Stephen Dorff Lili Taylor Sam Strike Alexandre Bustillo Julien Maury Ho...
# 20  Claire Holt Mandy Moore Chris Johnson Johannes Roberts Drama Thriller H...

# %%
old = pd.read_csv('C:/Users/SANTHOSH/Desktop/practise/flask/movie_recommandation/datasets/data.csv')
old.tail(20)
# Out:
#            director_name             actor_1_name        actor_2_name  \
# 5023          Daryl Wein         Zoe Lister-Jones       Heather Burns
# 5024         Jason Trost              Sean Whalen         Jason Trost
# 5025         John Waters                   Divine          Mink Stole
# 5026     Olivier Assayas            Maggie Cheung      Béatrice Dalle
# 5027        Jafar Panahi  Fereshteh Sadre Orafaiy   Nargess Mamizadeh
# 5028       Ivan Kavanagh        Patrick O'Donnell       Michael Parle
# 5029    Kiyoshi Kurosawa             Kôji Yakusho       Anna Nakagawa
# 5030        Tadeo Garcia      Tatiana Suarez-Pico      Michael Cortez
# 5031  Thomas L. Phillips            Julianna Pitt          Joe Coffey
# 5032     Ash Baron-Cohen             Peter Greene   Stanley B. Herman
# 5033       Shane Carruth            Shane Carruth      David Sullivan
# 5034    Neill Dela Llana              Ian Gamazon     Edgar Tancangco
# 5035    Robert Rodriguez          Carlos Gallardo     Peter Marquardt
# 5036     Anthony Vallone           Richard Jewell      John Considine
# 5037        Edward Burns              Kerry Bishé  Caitlin FitzGerald
# 5038         Scott Smith              Eric Mabius       Daphne Zuniga
# 5039             unknown              Natalie Zea       Valorie Curry
# 5040    Benjamin Roberds              Eva Boehnke       Maxwell Moody
# 5041         Daniel Hsia                Alan Ruck       Daniel Henney
# 5042            Jon Gunn              John August    Brian Herzlinger
#
#             actor_3_name                               genres  \
# 5023  Ebon Moss-Bachrach                              Romance
# 5024       Nick Principe                      Sci-Fi Thriller
# 5025        Edith Massey                  Comedy Crime Horror
# 5026        Don McKellar                  Drama Music Romance
# 5027    Mojgan Faramarzi                                Drama
# 5028    Emma Eliza Regan                               Horror
# 5029              Denden        Crime Horror Mystery Thriller
# 5030         Eric Ambriz                                Drama
# 5031          John Lucas               Comedy Horror Thriller
# 5032         James Noble                          Crime Drama
# 5033        Casey Gooden                Drama Sci-Fi Thriller
# 5034           Quynn Ton                             Thriller
# 5035      Consuelo Gómez  Action Crime Drama Romance Thriller
# 5036      Sara Stepnicka                          Crime Drama
# 5037     Daniella Pineda                         Comedy Drama
# 5038        Crystal Lowe                         Comedy Drama
# 5039       Sam Underwood         Crime Drama Mystery Thriller
# 5040      David Chandler                Drama Horror Thriller
# 5041         Eliza Coupe                 Comedy Drama Romance
# 5042            Jon Gunn                          Documentary
#
#                        movie_title
# 5023              breaking upwards
# 5024      all superheroes must die
# 5025                pink flamingos
# 5026                         clean
# 5027                    the circle
# 5028                   tin can man
# 5029                      the cure
# 5030                on the downlow
# 5031  sanctuary; quite a conundrum
# 5032                          bang
# 5033                        primer
# 5034                        cavite
# 5035                   el mariachi
# 5036               the mongol king
# 5037                     newlyweds
# 5038       signed sealed delivered
# 5039     the following
# 5040          a plague so pleasant
# 5041              shanghai calling
# 5042             my date with drew

# %%
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' '+ old['actor_3_name'] + ' '+ old['director_name'] +' ' + old['genres']

old.head(50)
# Out:
#         director_name          actor_1_name          actor_2_name  \
# 0       James Cameron           CCH Pounder      Joel David Moore
# 1      Gore Verbinski           Johnny Depp         Orlando Bloom
# 2          Sam Mendes       Christoph Waltz          Rory Kinnear
# 3   Christopher Nolan             Tom Hardy        Christian Bale
# 4         Doug Walker           Doug Walker            Rob Walker
# 5      Andrew Stanton          Daryl Sabara       Samantha Morton
# 6           Sam Raimi          J.K. Simmons          James Franco
# 7        Nathan Greno          Brad Garrett          Donna Murphy
# 8         Joss Whedon       Chris Hemsworth     Robert Downey Jr.
# 9         David Yates          Alan Rickman      Daniel Radcliffe
# 10        Zack Snyder          Henry Cavill          Lauren Cohan
# 11       Bryan Singer          Kevin Spacey         Marlon Brando
# 12       Marc Forster    Giancarlo Giannini       Mathieu Amalric
# 13     Gore Verbinski           Johnny Depp         Orlando Bloom
# 14     Gore Verbinski           Johnny Depp           Ruth Wilson
# 15        Zack Snyder          Henry Cavill    Christopher Meloni
# 16     Andrew Adamson        Peter Dinklage  Pierfrancesco Favino
# 17        Joss Whedon       Chris Hemsworth     Robert Downey Jr.
# 18       Rob Marshall           Johnny Depp           Sam Claflin
# 19   Barry Sonnenfeld            Will Smith     Michael Stuhlbarg
# 20      Peter Jackson          Aidan Turner            Adam Brown
# 21          Marc Webb            Emma Stone       Andrew Garfield
# 22       Ridley Scott             Mark Addy          William Hurt
# 23      Peter Jackson          Aidan Turner            Adam Brown
# 24        Chris Weitz       Christopher Lee             Eva Green
# 25      Peter Jackson           Naomi Watts    Thomas Kretschmann
# 26      James Cameron     Leonardo DiCaprio          Kate Winslet
# 27      Anthony Russo     Robert Downey Jr.    Scarlett Johansson
# 28         Peter Berg           Liam Neeson   Alexander Skarsgård
# 29    Colin Trevorrow   Bryce Dallas Howard            Judy Greer
# 30         Sam Mendes         Albert Finney         Helen McCrory
# 31          Sam Raimi          J.K. Simmons          James Franco
# 32        Shane Black     Robert Downey Jr.           Jon Favreau
# 33         Tim Burton           Johnny Depp          Alan Rickman
# 34       Brett Ratner          Hugh Jackman        Kelsey Grammer
# 35        Dan Scanlon         Steve Buscemi          Tyler Labine
# 36        Michael Bay       Glenn Morshower            Kevin Dunn
# 37        Michael Bay           Bingbing Li          Sophia Myles
# 38          Sam Raimi            Tim Holmes            Mila Kunis
# 39          Marc Webb            Emma Stone       Andrew Garfield
# 40    Joseph Kosinski          Jeff Bridges          Olivia Wilde
# 41      John Lasseter          Joe Mantegna    Thomas Kretschmann
# 42    Martin Campbell         Ryan Reynolds      Temuera Morrison
# 43        Lee Unkrich             Tom Hanks     John Ratzenberger
# 44                McG        Christian Bale   Bryce Dallas Howard
# 45          James Wan         Jason Statham           Paul Walker
# 46       Marc Forster         Peter Capaldi             Brad Pitt
# 47       Bryan Singer     Jennifer Lawrence        Peter Dinklage
# 48        J.J. Abrams  Benedict Cumberbatch       Bruce Greenwood
# 49       Bryan Singer          Eddie Marsan          Ewen Bremner
#
#             actor_3_name  \
# 0              Wes Studi
# 1         Jack Davenport
# 2       Stephanie Sigman
# 3   Joseph Gordon-Levitt
# 4                unknown
# 5           Polly Walker
# 6          Kirsten Dunst
# 7            M.C. Gainey
# 8     Scarlett Johansson
# 9           Rupert Grint
# 10        Alan D. Purwin
# 11        Frank Langella
# 12          Rory Kinnear
# 13        Jack Davenport
# 14         Tom Wilkinson
# 15          Harry Lennix
# 16        Damián Alcázar
# 17    Scarlett Johansson
# 18        Stephen Graham
# 19    Nicole Scherzinger
# 20         James Nesbitt
# 21           Chris Zylka
# 22          Scott Grimes
# 23         James Nesbitt
# 24  Kristin Scott Thomas
# 25            Evan Parke
# 26         Gloria Stuart
# 27           Chris Evans
# 28        Tadanobu Asano
# 29               Omar Sy
# 30          Rory Kinnear
# 31         Kirsten Dunst
# 32           Don Cheadle
# 33         Anne Hathaway
# 34        Daniel Cudmore
# 35            Sean Hayes
# 36       Ramon Rodriguez
# 37        Kelsey Grammer
# 38          James Franco
# 39            B.J. Novak
# 40           James Frain
# 41          Eddie Izzard
# 42         Taika Waititi
# 43           Don Rickles
# 44                Common
# 45            Vin Diesel
# 46         Mireille Enos
# 47          Hugh Jackman
# 48           Noel Clarke
# 49           Ralph Brown
#
#                                                        genres  \
# 0                             Action Adventure Fantasy Sci-Fi
# 1                                    Action Adventure Fantasy
# 2                                   Action Adventure Thriller
# 3                                             Action Thriller
# 4                                                 Documentary
# 5                                     Action Adventure Sci-Fi
# 6                                    Action Adventure Romance
# 7   Adventure Animation Comedy Family Fantasy Musical Romance
# 8                                     Action Adventure Sci-Fi
# 9                            Adventure Family Fantasy Mystery
# 10                                    Action Adventure Sci-Fi
# 11                                    Action Adventure Sci-Fi
# 12                                           Action Adventure
# 13                                   Action Adventure Fantasy
# 14                                   Action Adventure Western
# 15                            Action Adventure Fantasy Sci-Fi
# 16                            Action Adventure Family Fantasy
# 17                                    Action Adventure Sci-Fi
# 18                                   Action Adventure Fantasy
# 19              Action Adventure Comedy Family Fantasy Sci-Fi
# 20                                          Adventure Fantasy
# 21                                   Action Adventure Fantasy
# 22                             Action Adventure Drama History
# 23                                          Adventure Fantasy
# 24                                   Adventure Family Fantasy
# 25                             Action Adventure Drama Romance
# 26                                              Drama Romance
# 27                                    Action Adventure Sci-Fi
# 28                           Action Adventure Sci-Fi Thriller
# 29                           Action Adventure Sci-Fi Thriller
# 30                                  Action Adventure Thriller
# 31                           Action Adventure Fantasy Romance
# 32                                    Action Adventure Sci-Fi
# 33                                   Adventure Family Fantasy
# 34                   Action Adventure Fantasy Sci-Fi Thriller
# 35                  Adventure Animation Comedy Family Fantasy
# 36                                    Action Adventure Sci-Fi
# 37                                    Action Adventure Sci-Fi
# 38                                   Adventure Family Fantasy
# 39                            Action Adventure Fantasy Sci-Fi
# 40                                    Action Adventure Sci-Fi
# 41                    Adventure Animation Comedy Family Sport
# 42                                    Action Adventure Sci-Fi
# 43                  Adventure Animation Comedy Family Fantasy
# 44                                    Action Adventure Sci-Fi
# 45                                      Action Crime Thriller
# 46                    Action Adventure Horror Sci-Fi Thriller
# 47                   Action Adventure Fantasy Sci-Fi Thriller
# 48                                    Action Adventure Sci-Fi
# 49                                          Adventure Fantasy
#
#                                                movie_title  \
# 0                                                   avatar
# 1                 pirates of the caribbean: at world's end
# 2                                                  spectre
# 3                                    the dark knight rises
# 4   star wars: episode vii - the force awakens
# 5                                              john carter
# 6                                             spider-man 3
# 7                                                  tangled
# 8                                  avengers: age of ultron
# 9                   harry potter and the half-blood prince
# 10                      batman v superman: dawn of justice
# 11                                        superman returns
# 12                                       quantum of solace
# 13              pirates of the caribbean: dead man's chest
# 14                                         the lone ranger
# 15                                            man of steel
# 16                the chronicles of narnia: prince caspian
# 17                                            the avengers
# 18             pirates of the caribbean: on stranger tides
# 19                                          men in black 3
# 20               the hobbit: the battle of the five armies
# 21                                  the amazing spider-man
# 22                                              robin hood
# 23                     the hobbit: the desolation of smaug
# 24                                      the golden compass
# 25                                               king kong
# 26                                                 titanic
# 27                              captain america: civil war
# 28                                              battleship
# 29                                          jurassic world
# 30                                                 skyfall
# 31                                            spider-man 2
# 32                                              iron man 3
# 33                                     alice in wonderland
# 34                                   x-men: the last stand
# 35                                     monsters university
# 36                     transformers: revenge of the fallen
# 37                         transformers: age of extinction
# 38                               oz the great and powerful
# 39                                the amazing spider-man 2
# 40                                            tron: legacy
# 41                                                  cars 2
# 42                                           green lantern
# 43                                             toy story 3
# 44                                    terminator salvation
# 45                                               furious 7
# 46                                             world war z
# 47                              x-men: days of future past
# 48                                 star trek into darkness
# 49                                   jack the giant slayer
#
#                                                                           comb
# 0   CCH Pounder Joel David Moore Wes Studi James Cameron Action Adventure F...
# 1   Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski Action Adventur...
# 2   Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes Action Adventu...
# 3   Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan Action ...
# 4                       Doug Walker Rob Walker unknown Doug Walker Documentary
# 5   Daryl Sabara Samantha Morton Polly Walker Andrew Stanton Action Adventu...
# 6   J.K. Simmons James Franco Kirsten Dunst Sam Raimi Action Adventure Romance
# 7   Brad Garrett Donna Murphy M.C. Gainey Nathan Greno Adventure Animation ...
# 8   Chris Hemsworth Robert Downey Jr. Scarlett Johansson Joss Whedon Action...
# 9   Alan Rickman Daniel Radcliffe Rupert Grint David Yates Adventure Family...
# 10  Henry Cavill Lauren Cohan Alan D. Purwin Zack Snyder Action Adventure S...
# 11  Kevin Spacey Marlon Brando Frank Langella Bryan Singer Action Adventure...
# 12  Giancarlo Giannini Mathieu Amalric Rory Kinnear Marc Forster Action Adv...
# 13  Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski Action Adventur...
# 14  Johnny Depp Ruth Wilson Tom Wilkinson Gore Verbinski Action Adventure W...
# 15  Henry Cavill Christopher Meloni Harry Lennix Zack Snyder Action Adventu...
# 16  Peter Dinklage Pierfrancesco Favino Damián Alcázar Andrew Adamson Actio...
# 17  Chris Hemsworth Robert Downey Jr. Scarlett Johansson Joss Whedon Action...
# 18  Johnny Depp Sam Claflin Stephen Graham Rob Marshall Action Adventure Fa...
# 19  Will Smith Michael Stuhlbarg Nicole Scherzinger Barry Sonnenfeld Action...
# 20       Aidan Turner Adam Brown James Nesbitt Peter Jackson Adventure Fantasy
# 21   Emma Stone Andrew Garfield Chris Zylka Marc Webb Action Adventure Fantasy
# 22  Mark Addy William Hurt Scott Grimes Ridley Scott Action Adventure Drama...
# 23       Aidan Turner Adam Brown James Nesbitt Peter Jackson Adventure Fantasy
# 24  Christopher Lee Eva Green Kristin Scott Thomas Chris Weitz Adventure Fa...
# 25  Naomi Watts Thomas Kretschmann Evan Parke Peter Jackson Action Adventur...
# 26    Leonardo DiCaprio Kate Winslet Gloria Stuart James Cameron Drama Romance
# 27  Robert Downey Jr. Scarlett Johansson Chris Evans Anthony Russo Action A...
# 28  Liam Neeson Alexander Skarsgård Tadanobu Asano Peter Berg Action Advent...
# 29  Bryce Dallas Howard Judy Greer Omar Sy Colin Trevorrow Action Adventure...
# 30  Albert Finney Helen McCrory Rory Kinnear Sam Mendes Action Adventure Th...
# 31  J.K. Simmons James Franco Kirsten Dunst Sam Raimi Action Adventure Fant...
# 32  Robert Downey Jr. Jon Favreau Don Cheadle Shane Black Action Adventure ...
# 33  Johnny Depp Alan Rickman Anne Hathaway Tim Burton Adventure Family Fantasy
# 34  Hugh Jackman Kelsey Grammer Daniel Cudmore Brett Ratner Action Adventur...
# 35  Steve Buscemi Tyler Labine Sean Hayes Dan Scanlon Adventure Animation C...
# 36  Glenn Morshower Kevin Dunn Ramon Rodriguez Michael Bay Action Adventure...
# 37  Bingbing Li Sophia Myles Kelsey Grammer Michael Bay Action Adventure Sc...
# 38       Tim Holmes Mila Kunis James Franco Sam Raimi Adventure Family Fantasy
# 39  Emma Stone Andrew Garfield B.J. Novak Marc Webb Action Adventure Fantas...
# 40  Jeff Bridges Olivia Wilde James Frain Joseph Kosinski Action Adventure ...
# 41  Joe Mantegna Thomas Kretschmann Eddie Izzard John Lasseter Adventure An...
# 42  Ryan Reynolds Temuera Morrison Taika Waititi Martin Campbell Action Adv...
# 43  Tom Hanks John Ratzenberger Don Rickles Lee Unkrich Adventure Animation...
# 44       Christian Bale Bryce Dallas Howard Common McG Action Adventure Sci-Fi
# 45        Jason Statham Paul Walker Vin Diesel James Wan Action Crime Thriller
# 46  Peter Capaldi Brad Pitt Mireille Enos Marc Forster Action Adventure Hor...
# 47  Jennifer Lawrence Peter Dinklage Hugh Jackman Bryan Singer Action Adven...
# 48  Benedict Cumberbatch Bruce Greenwood Noel Clarke J.J. Abrams Action Adv...
# 49        Eddie Marsan Ewen Bremner Ralph Brown Bryan Singer Adventure Fantasy

# %%
new = old.append(movie)
new.head(100)
# Out:
#         director_name         actor_1_name       actor_2_name  \
# 0       James Cameron          CCH Pounder   Joel David Moore
# 1      Gore Verbinski          Johnny Depp      Orlando Bloom
# 2          Sam Mendes      Christoph Waltz       Rory Kinnear
# 3   Christopher Nolan            Tom Hardy     Christian Bale
# 4         Doug Walker          Doug Walker         Rob Walker
# ..                ...                  ...                ...
# 95         James Gunn       Bradley Cooper         Vin Diesel
# 96  Christopher Nolan  Matthew McConaughey      Anne Hathaway
# 97  Christopher Nolan    Leonardo DiCaprio          Tom Hardy
# 98       Hideaki Anno        Mark Chinnery  Shin'ya Tsukamoto
# 99      Peter Jackson         Aidan Turner         Adam Brown
#
#             actor_3_name                                genres  \
# 0              Wes Studi       Action Adventure Fantasy Sci-Fi
# 1         Jack Davenport              Action Adventure Fantasy
# 2       Stephanie Sigman             Action Adventure Thriller
# 3   Joseph Gordon-Levitt                       Action Thriller
# 4                unknown                           Documentary
# ..                   ...                                   ...
# 95        Djimon Hounsou               Action Adventure Sci-Fi
# 96         Mackenzie Foy                Adventure Drama Sci-Fi
# 97  Joseph Gordon-Levitt      Action Adventure Sci-Fi Thriller
# 98          Atsuko Maeda  Action Adventure Drama Horror Sci-Fi
# 99         James Nesbitt                     Adventure Fantasy
#
#                                                movie_title  \
# 0                                                   avatar
# 1                 pirates of the caribbean: at world's end
# 2                                                  spectre
# 3                                    the dark knight rises
# 4   star wars: episode vii - the force awakens
# ..                                                     ...
# 95                                 guardians of the galaxy
# 96                                            interstellar
# 97                                               inception
# 98                                     godzilla resurgence
# 99                       the hobbit: an unexpected journey
#
#                                                                           comb
# 0   CCH Pounder Joel David Moore Wes Studi James Cameron Action Adventure F...
# 1   Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski Action Adventur...
# 2   Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes Action Adventu...
# 3   Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan Action ...
# 4                       Doug Walker Rob Walker unknown Doug Walker Documentary
# ..                                                                         ...
# 95  Bradley Cooper Vin Diesel Djimon Hounsou James Gunn Action Adventure Sc...
# 96  Matthew McConaughey Anne Hathaway Mackenzie Foy Christopher Nolan Adven...
# 97  Leonardo DiCaprio Tom Hardy Joseph Gordon-Levitt Christopher Nolan Acti...
# 98  Mark Chinnery Shin'ya Tsukamoto Atsuko Maeda Hideaki Anno Action Advent...
# 99       Aidan Turner Adam Brown James Nesbitt Peter Jackson Adventure Fantasy
#
# [100 rows x 7 columns]

# %%
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)
new.tail()
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#           actor_3_name                      genres  \
# 524    Keith Stanfield              Romance Comedy
# 525  Jean Louisa Kelly                     Romance
# 526     Tiitus Rantala              Romance Comedy
# 527        Gina Holden  Crime Comedy Action Family
# 529     Akshaye Khanna        Crime Drama Thriller
#
#                           movie_title  \
# 524      the incredible jessica james
# 525                 can't buy my love
# 526  thick lashes of lauri mäntyvaara
# 527       cop and a half: new recruit
# 529                               mom
#
#                                                                            comb
# 524    Jessica Williams Chris O'Dowd Keith Stanfield Jim Strouse Romance Comedy
# 525  Adelaide Kane Benjamin Hollingsworth Jean Louisa Kelly Farhad Mann Romance
# 526  Inka Haapamäki Rosa Honkonen Tiitus Rantala Hannaleena Hauru Romance Co...
# 527  Lou Diamond Phillips Wallace Shawn Gina Holden Jonathan A. Rosenbaum Cr...
# 529   Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi Udyawar Crime Drama Thriller

# %%
new.to_csv('C:/Users/SANTHOSH/Desktop/practise/flask/movie_recommandation/datasets/new_data.csv',index=False)
